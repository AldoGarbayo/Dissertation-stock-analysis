# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
PFE_data = pd.read_csv('/Users/Aldo/Desktop/WESTMINSTER/DISSERTATION/Coding analysis/Sentiment stocks/Databases/Pfizer Weekly Trend.csv', index_col = 'Week')
PFE_data.head()
# Out:
#             Trend      Price
# Week
# 20/09/2020      3  32.866081
# 27/09/2020      4  33.166935
# 04/10/2020      4  33.540726
# 11/10/2020      5  34.598278
# 18/10/2020      6  34.807957

# %%
PFE_data.index = pd.to_datetime(PFE_data.index)
PFE_data.head()
# Out:
#             Trend      Price
# Week
# 2020-09-20      3  32.866081
# 2020-09-27      4  33.166935
# 2020-04-10      4  33.540726
# 2020-11-10      5  34.598278
# 2020-10-18      6  34.807957

# %%
PFE_data['Trend'].plot(label = 'Trend',figsize = (16,8), title = 'Trend and stock movements')
PFE_data['Price'].plot(label = 'Price')
plt.legend()

# %%
PFE_data.corr()
# Out:
#           Trend     Price
# Trend  1.000000  0.284415
# Price  0.284415  1.000000

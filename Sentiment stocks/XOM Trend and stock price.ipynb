# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
XOM_data = pd.read_csv('/Users/Aldo/Desktop/WESTMINSTER/DISSERTATION/Coding analysis/Sentiment stocks/Databases/XOM Weekly Trend.csv', index_col = 'Week')
XOM_data.head()
# Out:
#             Trend      Price
# Week
# 20/09/2020     78  32.292797
# 27/09/2020     69  30.745279
# 04/10/2020     78  32.386024
# 11/10/2020     71  31.789385
# 18/10/2020     92  31.845322

# %%
XOM_data.index = pd.to_datetime(XOM_data.index)
XOM_data.head()
# Out:
#             Trend      Price
# Week
# 2020-09-20     78  32.292797
# 2020-09-27     69  30.745279
# 2020-04-10     78  32.386024
# 2020-11-10     71  31.789385
# 2020-10-18     92  31.845322

# %%
XOM_data['Trend'].plot(label = 'Trend',figsize = (16,8), title = 'Trend and stock movements')
XOM_data['Price'].plot(label = 'Price')
plt.legend()

# %%
XOM_data.corr()
# Out:
#           Trend     Price
# Trend  1.000000  0.235327
# Price  0.235327  1.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
AAL_data = pd.read_csv('/Users/Aldo/Desktop/WESTMINSTER/DISSERTATION/Coding analysis/Sentiment stocks/Databases/AAL Weekly Trend .csv', index_col = 'Week')
AAL_data
# Out:
#             Trend      Price
# Week
# 20/09/2020     39  12.290000
# 27/09/2020     42  13.000000
# 04/10/2020     44  13.200000
# 11/10/2020     45  12.460000
# 18/10/2020     45  12.600000
# 25/10/2020     41  11.280000
# 01/11/2020     35  11.460000
# 08/11/2020     43  12.240000
# 15/11/2020     40  12.530000
# 22/11/2020     39  14.980000
# 29/11/2020     40  16.400000
# 06/12/2020     39  17.049999
# 13/12/2020     42  16.510000
# 20/12/2020     39  15.660000
# 27/12/2020     44  15.770000
# 03/01/2021     43  15.130000
# 10/01/2021     40  15.760000
# 17/01/2021     38  15.820000
# 24/01/2021     46  17.170000
# 31/01/2021     43  17.190001
# 07/02/2021     45  17.270000
# 14/02/2021     52  18.680000
# 21/02/2021     53  20.940001
# 28/02/2021     56  20.450001
# 07/03/2021     60  23.370001
# 14/03/2021     61  24.969999
# 21/03/2021     63  22.930000
# 28/03/2021     61  23.860001
# 04/04/2021     63  23.540001
# 11/04/2021     66  22.030001
# 18/04/2021     68  21.110001
# ...

# %%
AAL_data.index = pd.to_datetime(AAL_data.index)
AAL_data.head()
# Out:
#             Trend  Price
# Week
# 2020-09-20     39  12.29
# 2020-09-27     42  13.00
# 2020-04-10     44  13.20
# 2020-11-10     45  12.46
# 2020-10-18     45  12.60

# %%
AAL_data['Trend'].plot(label = 'Trend',figsize = (16,8), title = 'Trend and stock movements')
AAL_data['Price'].plot(label = 'Price')
plt.legend()

# %%
AAL_data['Trend'].plot(label = 'Trend',figsize = (16,8), title = 'Trend and stock movements')
AAL_data['Price'].plot(label = 'Price')
plt.legend()

# %%
AAL_data.corr()
# Out:
#           Trend     Price
# Trend  1.000000  0.780075
# Price  0.780075  1.000000
